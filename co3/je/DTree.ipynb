# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt

# %%
f=pd.read_csv('data.csv')
# Out:
#          name  gives_birth  aquatic_animal  aerial_animal  has_legs  \
# 0       human            1               0              0         1
# 1      python            0               0              0         0
# 2      salmon            0               1              0         0
# 3        frog            0               2              0         1
# 4         bat            1               0              1         1
# 5      pigeon            0               0              1         1
# 6         cat            1               0              0         1
# 7       shark            1               1              0         0
# 8      turtle            0               2              0         1
# 9  salamander            0               2              0         1
#
#   class_label
# 0      mammal
# 1     reptile
# 2        fish
# 3   ampbibian
# 4        bird
# 5        bird
# 6      mammal
# 7        fish
# 8   amphibian
# 9   amphibian

# %%
x=f.drop(columns=['class_label','name'])
y=f['class_label']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.4)

# %%
dt=DecisionTreeClassifier()
dt.fit(xtrain,ytrain.values.ravel())
p=dt.predict(xtest)
# Out:
# array(['reptile', 'mammal', 'reptile', 'mammal'], dtype=object)

# %%
ft=['gives_birth','aquatic_animal','aerial_animal','has_legs']
c=['mammal','reptile','fish','ampbibian','bird']
plt.figure(figsize=(10,10))
tree.plot_tree(dt,
              feature_names=ft,
              class_names=c,
              filled=True)
# Out:
# [Text(0.6, 0.8333333333333334, 'gives_birth <= 0.5\ngini = 0.722\nsamples = 6\nvalue = [1, 2, 2, 1]\nclass = reptile'),
#  Text(0.4, 0.5, 'aquatic_animal <= 1.0\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 0, 1]\nclass = reptile'),
#  Text(0.2, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = ampbibian'),
#  Text(0.6, 0.16666666666666666, 'gini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0]\nclass = reptile'),
#  Text(0.8, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = fish')]
